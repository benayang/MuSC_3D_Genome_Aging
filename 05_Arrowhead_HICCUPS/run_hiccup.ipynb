# %%
# !wget https://s3.amazonaws.com/hicfiles.tc4ga.com/public/juicer/juicer_tools_1.22.01.jar
# Out:
# --2022-01-31 03:37:33--  https://s3.amazonaws.com/hicfiles.tc4ga.com/public/juicer/juicer_tools_1.22.01.jar
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.217.142.104
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.217.142.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36188666 (35M) [application/x-www-form-urlencoded]
# Saving to: ‘juicer_tools_1.22.01.jar’
#
# juicer_tools_1.22.0 100%[===================>]  34.51M  8.46MB/s    in 5.8s
#
# 2022-01-31 03:37:39 (5.94 MB/s) - ‘juicer_tools_1.22.01.jar’ saved [36188666/36188666]

# %%
import time

# %%
tic=time.perf_counter()
# !java -Xmx10g -jar juicer_tools_1.22.01.jar hiccups --threads 0 -k KR /content/drive/MyDrive/HiC/aged.merged.hic /content/drive/MyDrive/HiC/aged_merged_hiccups
toc=time.perf_counter()
print(f"Ran Hiccups on Aged in {(toc - tic)/60:0.4f} minutes")
# Out:
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# WARN [2022-01-22T07:09:36,520]  [Globals.java:138] [main]  Development mode is enabled
# Reading file: /content/drive/MyDrive/HiC/aged.merged.hic
# No valid configurations specified, using default settings
# Using 1 CPU thread(s)
# Default settings for 5kb, 10kb, and 25kb being used
# Running HiCCUPS for resolution 5000
# 4%
# 9%
# 14%
# 19%
# 24%
# 29%
# 34%
# 39%
# 44%
# 49%
# 54%
# 59%
# 64%
# 69%
# 74%
# 79%
# 84%
# 89%
# 94%
# 99%
# 4%
# 9%
# 14%
# 19%
# 24%
# 29%
# 34%
# 39%
# 44%
# 49%
# 54%
# 59%
# 64%
# 69%
# 74%
# 79%
# 84%
# 89%
# 94%
# 99%
# 637 features written to file: /content/drive/MyDrive/HiC/aged_merged_hiccups/enriched_pixels_5000.bedpe
# Running HiCCUPS for resolution 10000
# 4%
# 9%
# 14%
# 19%
# 24%
# 29%
# 34%
# 39%
# 44%
# 49%
# 54%
# 59%
# 64%
# 69%
# 74%
# 79%
# 84%
# 89%
# 94%
# 99%
# 4%
# 9%
# 14%
# 19%
# 24%
# 29%
# 34%
# 39%
# 44%
# 49%
# 54%
# 59%
# 64%
# ...

# %%
tic=time.perf_counter()
# !java -Xmx10g -jar juicer_tools_1.22.01.jar hiccups --threads 0 -k KR /content/drive/MyDrive/HiC/young.merged.hic /content/drive/MyDrive/HiC/young_merged_hiccups
toc=time.perf_counter()
print(f"Ran Hiccups on Young in {(toc - tic)/60:0.4f} minutes")
# Out:
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# WARN [2022-01-22T18:27:34,996]  [Globals.java:138] [main]  Development mode is enabled
# Reading file: /content/drive/MyDrive/HiC/young.merged.hic
# No valid configurations specified, using default settings
# Using 1 CPU thread(s)
# Default settings for 5kb, 10kb, and 25kb being used
# Running HiCCUPS for resolution 5000
# 4%
# 9%
# 14%
# 19%
# 24%
# 29%
# 34%
# 39%
# 44%
# 49%
# 54%
# 59%
# 64%
# 69%
# 74%
# 79%
# 84%
# 89%
# 94%
# 99%
# 4%
# 9%
# 14%
# 19%
# 24%
# 29%
# 34%
# 39%
# 44%
# 49%
# 54%
# 59%
# 64%
# 69%
# 74%
# 79%
# 84%
# 89%
# 94%
# 99%
# 1061 features written to file: /content/drive/MyDrive/HiC/young_merged_hiccups/enriched_pixels_5000.bedpe
# Running HiCCUPS for resolution 10000
# 4%
# 9%
# 14%
# 19%
# 24%
# 29%
# 34%
# 39%
# 44%
# 49%
# 54%
# 59%
# 64%
# 69%
# 74%
# 79%
# 84%
# 89%
# 94%
# 99%
# 4%
# 9%
# 14%
# 19%
# 24%
# 29%
# 34%
# 39%
# 44%
# 49%
# 54%
# 59%
# 64%
# ...

# %%
# !java -Xmx10g -jar juicer_tools_1.22.01.jar hiccupsdiff -k KR /content/drive/MyDrive/HiC/young.merged.hic /content/drive/MyDrive/HiC/aged.merged.hic /content/drive/MyDrive/HiC/young_merged_hiccups/merged_loops.bedpe /content/drive/MyDrive/HiC/aged_merged_hiccups/merged_loops.bedpe /content/drive/MyDrive/HiC/hiccups_diff
# Out:
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# WARN [2022-01-31T03:40:10,671]  [Globals.java:138] [main]  Development mode is enabled
# Reading file: /content/drive/MyDrive/HiC/young.merged.hic
# Reading file: /content/drive/MyDrive/HiC/aged.merged.hic
# Running differential HiCCUPs with resolutions:
# Config res: 5000 peak: 4 window: 7 fdr: 10% radius: 20000
# Config res: 10000 peak: 2 window: 5 fdr: 10% radius: 20000
# Config res: 25000 peak: 1 window: 3 fdr: 10% radius: 50000
# Using 1 CPU thread(s)
# Running HiCCUPS with alternate loop lists
# Running HiCCUPS for resolution 5000
# 4%
# 9%
# 14%
# 19%
# 24%
# 29%
# 34%
# 39%
# 44%
# 49%
# 54%
# 59%
# 64%
# 69%
# 74%
# 79%
# 84%
# 89%
# 94%
# 99%
# 4%
# 9%
# 14%
# 19%
# 24%
# 29%
# 34%
# 39%
# 44%
# 49%
# 54%
# 59%
# 64%
# 69%
# 74%
# 79%
# 84%
# 89%
# 94%
# returning all; key 22_22 not found contained
# returning all; key 22_22 not found contained
# ...
